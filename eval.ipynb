# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for models
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

sql_eval_scores = [86, 82, 78, 72, 68, 62]  # SqlEval-Classic Scores (%)
execution_accuracy = [91, 89, 84, 80, 72, 76]  # Execution Accuracy (%)
query_optimization = [88, 85, 86, 80, 76, 69]  # Query Optimization (%)
latency = [120, 110, 150, 130, 170, 190]  # Latency (ms)

# Set style
sns.set_theme(style="whitegrid")

# Create figure and axes
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

# Bar Chart - SqlEval Scores
bar_plot = sns.barplot(x=sql_eval_scores, y=models, ax=axes[0], palette="Blues_r")
axes[0].set_title("SqlEval-Classic Scores (%)")
axes[0].set_xlabel("Score")
axes[0].set_ylabel("LLM Models")

# Add data labels to the bar chart
for container in axes[0].containers:
    axes[0].bar_label(container, fmt="%.1f", label_type="edge", padding=3)

# Line Chart - Latency
axes[1].plot(models, latency, marker='o', linestyle='-', color='red', label="Latency (ms)")
axes[1].set_title("Latency Comparison (ms)")
axes[1].set_ylabel("Latency (ms)")
axes[1].set_xlabel("LLM Models")
axes[1].legend()

# Rotate x-axis labels to prevent text overflow
axes[1].set_xticklabels(models, rotation=30, ha="right")

# Add data labels to the line chart
for i, txt in enumerate(latency):
    axes[1].text(i, txt + 5, f"{txt} ms", ha="center", fontsize=10, color='black')

# Heatmap - Performance Metrics
# data_matrix = np.array([sql_eval_scores, execution_accuracy, query_optimization, latency])
# heatmap_data = np.transpose(data_matrix)  # Transpose for correct mapping

# sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="coolwarm",
#             xticklabels=["SqlEval", "Exec Acc", "Query Opt", "Latency"],
#             yticklabels=models, ax=axes[2])
# axes[2].set_title("Performance Metrics Heatmap")

# plt.tight_layout()
# plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\1878111771.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x=sql_eval_scores, y=models, ax=axes[0], palette="Blues_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\1878111771.py:40: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(models, rotation=30, ha="right")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for models
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

sql_eval_scores = [86, 82, 78, 72, 68, 62]  # SqlEval-Classic Scores (%)
execution_accuracy = [91, 89, 84, 80, 72, 76]  # Execution Accuracy (%)
query_optimization = [88, 85, 86, 80, 76, 69]  # Query Optimization (%)
latency = [120, 110, 150, 130, 170, 190]  # Latency (ms)

# Set style
sns.set_theme(style="whitegrid")

### 1. Bar Chart - SqlEval Scores
fig, ax = plt.subplots(figsize=(6, 4))  # Same size for consistency
sns.barplot(x=sql_eval_scores, y=models, ax=ax, palette="Blues_r")
ax.set_title("SqlEval-Classic Scores (%)")
ax.set_xlabel("Score")
ax.set_ylabel("LLM Models")

# Add data labels
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=3)

plt.tight_layout()
plt.savefig("sql_eval_scores.png", dpi=300)  # Save for journal
plt.show()

### 2. Line Chart - Latency
fig, ax = plt.subplots(figsize=(6, 4))  
ax.plot(models, latency, marker='o', linestyle='-', color='red', label="Latency (ms)")
ax.set_title("Latency Comparison (ms)")
ax.set_ylabel("Latency (ms)")
ax.set_xlabel("LLM Models")
ax.legend()

# Rotate x-axis labels
ax.set_xticklabels(models, rotation=30, ha="right")

# Add data labels
for i, txt in enumerate(latency):
    ax.text(i, txt + 5, f"{txt} ms", ha="center", fontsize=10, color='black')

plt.tight_layout()
plt.savefig("latency_comparison.png", dpi=300)  # Save for journal
plt.show()

### 3. Heatmap - Performance Metrics
fig, ax = plt.subplots(figsize=(6, 4))  
data_matrix = np.array([sql_eval_scores, execution_accuracy, query_optimization, latency])
heatmap_data = np.transpose(data_matrix)  # Transpose for correct mapping

sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap="coolwarm",
            xticklabels=["SqlEval", "Exec Acc", "Query Opt", "Latency"],
            yticklabels=models, ax=ax)
ax.set_title("Performance Metrics Heatmap")

plt.tight_layout()
plt.savefig("performance_metrics_heatmap.png", dpi=300)  # Save for journal
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\618872031.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sql_eval_scores, y=models, ax=ax, palette="Blues_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\618872031.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(models, rotation=30, ha="right")

# %%
# Re-import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Re-define data for models
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

sql_eval_scores = [86, 82, 78, 72, 68, 62]  # SqlEval-Classic Scores (%)
execution_accuracy = [91, 89, 84, 80, 72, 76]  # Execution Accuracy (%)
query_optimization = [88, 85, 86, 80, 76, 69]  # Query Optimization (%)
latency = [120, 110, 150, 130, 170, 190]  # Latency (ms)

# Additional Evaluation Metrics
sql_syntax_correctness = [94, 91, 88, 82, 74, 78]  # SQL Syntax Correctness (%)
join_handling = [90, 87, 83, 75, 79, 70]  # Join Handling (%)
aggregation_accuracy = [92, 84, 89, 81, 77, 72]  # Aggregation Accuracy (%)
nested_query_performance = [84, 88, 80, 72, 76, 68]  # Nested Query Performance (%)

# Expanded Data Matrix for Heatmap
expanded_data_matrix = np.array([
    sql_eval_scores, execution_accuracy, query_optimization, latency, 
    sql_syntax_correctness, join_handling, aggregation_accuracy, nested_query_performance
])
expanded_heatmap_data = np.transpose(expanded_data_matrix)  # Transpose for correct mapping

# Set seaborn style
sns.set_theme(style="whitegrid")

### 1. Bar Chart - SQL Syntax Correctness
fig, ax = plt.subplots(figsize=(6, 4))
sns.barplot(x=sql_syntax_correctness, y=models, ax=ax, palette="Greens_r")
ax.set_title("SQL Syntax Correctness (%)")
ax.set_xlabel("Score")
ax.set_ylabel("LLM Models")

# Add data labels
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=3)

plt.tight_layout()
plt.savefig("sql_syntax_correctness.png", dpi=300)  # Save for journal
plt.show()

### 2. Line Chart - Nested Query Performance
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(models, nested_query_performance, marker='s', linestyle='-', color='purple', label="Nested Query Performance (%)")
ax.set_title("Nested Query Performance (%)")
ax.set_ylabel("Performance (%)")
ax.set_xlabel("LLM Models")
ax.legend()

# Rotate x-axis labels
ax.set_xticklabels(models, rotation=30, ha="right")

# Add data labels
for i, txt in enumerate(nested_query_performance):
    ax.text(i, txt + 1, f"{txt}%", ha="center", fontsize=10, color='black')

plt.tight_layout()
plt.savefig("nested_query_performance.png", dpi=300)  # Save for journal
plt.show()

### 3. Heatmap - Extended Metrics
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(expanded_heatmap_data, annot=True, fmt=".0f", cmap="coolwarm",
            xticklabels=["SqlEval", "Exec Acc", "Query Opt", "Latency", "SQL Syntax", "Joins", "Aggregations", "Nested Queries"],
            yticklabels=models, ax=ax)
ax.set_title("Expanded Performance Metrics Heatmap")

plt.tight_layout()
plt.savefig("expanded_performance_heatmap.png", dpi=300)  # Save for journal
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\3271647934.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sql_syntax_correctness, y=models, ax=ax, palette="Greens_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\3271647934.py:57: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(models, rotation=30, ha="right")

# %%
# Re-import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Re-define data for models
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

sql_eval_scores = [86, 82, 78, 72, 68, 62]  # SqlEval-Classic Scores (%)
execution_accuracy = [91, 89, 84, 80, 72, 76]  # Execution Accuracy (%)
query_optimization = [88, 85, 86, 80, 76, 69]  # Query Optimization (%)
latency = [120, 110, 150, 130, 170, 190]  # Latency (ms)

# Additional Evaluation Metrics
sql_syntax_correctness = [94, 91, 88, 82, 74, 78]  # SQL Syntax Correctness (%)
join_handling = [90, 87, 83, 75, 79, 70]  # Join Handling (%)
aggregation_accuracy = [92, 84, 89, 81, 77, 72]  # Aggregation Accuracy (%)
nested_query_performance = [84, 88, 80, 72, 76, 68]  # Nested Query Performance (%)

# Expanded Data Matrix for Heatmap
expanded_data_matrix = np.array([ 
    sql_eval_scores, execution_accuracy, query_optimization, latency, 
    sql_syntax_correctness, join_handling, aggregation_accuracy, nested_query_performance
])
expanded_heatmap_data = np.transpose(expanded_data_matrix)  # Transpose for correct mapping

# Set seaborn style
sns.set_theme(style="whitegrid")

# Create subplot figure
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

### 1. SQL Syntax Correctness - Bar Chart
sns.barplot(x=sql_syntax_correctness, y=models, ax=axes[0], palette="Greens_r")
axes[0].set_title("SQL Syntax Correctness (%)")
axes[0].set_xlabel("Score")
axes[0].set_ylabel("LLM Models")

# Add data labels
for container in axes[0].containers:
    axes[0].bar_label(container, fmt="%.1f", label_type="edge", padding=3)

### 2. Nested Query Performance - Line Chart
axes[1].plot(models, nested_query_performance, marker='s', linestyle='-', color='purple', label="Nested Query Performance (%)")
axes[1].set_title("Nested Query Performance (%)")
axes[1].set_ylabel("Performance (%)")
axes[1].set_xlabel("LLM Models")
axes[1].legend()

# Rotate x-axis labels for better readability
axes[1].set_xticklabels(models, rotation=30, ha="right")

# Add data labels to the line chart
for i, txt in enumerate(nested_query_performance):
    axes[1].text(i, txt + 1, f"{txt}%", ha="center", fontsize=10, color='black')

# Adjust layout for subplots
plt.tight_layout()

# Save the figure
plt.savefig("sql_syntax_and_nested_query_performance.png", dpi=300)  # Save for journal
plt.show()

# Create Heatmap for expanded metrics
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(expanded_heatmap_data, annot=True, fmt=".0f", cmap="coolwarm",
            xticklabels=["SqlEval", "Exec Acc", "Query Opt", "Latency", "SQL Syntax", "Joins", "Aggregations", "Nested Queries"],
            yticklabels=models, ax=ax)
ax.set_title("Expanded Performance Metrics Heatmap")

# Save heatmap
plt.tight_layout()
plt.savefig("expanded_performance_heatmap.png", dpi=300)  # Save for journal
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\1629896329.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sql_syntax_correctness, y=models, ax=axes[0], palette="Greens_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\1629896329.py:54: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(models, rotation=30, ha="right")

# %%
# Re-import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Re-define models
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

# New SQL Execution Evaluation Metrics
select_queries = [88, 95, 89, 86, 82, 76]  # SELECT Queries (%)
insert_queries = [90, 87, 84, 80, 76, 72]  # INSERT Queries (%)
update_queries = [88, 85, 81, 78, 74, 70]  # UPDATE Queries (%)
delete_queries = [87, 79, 84, 71, 75, 68]  # DELETE Queries (%)
join_performance = [91, 88, 85, 81, 77, 72]  # JOIN Performance (%)
transaction_handling = [89, 82, 86, 78, 74, 62]  # Transaction Handling (%)

# Additional Existing Metrics
join_handling = [90, 87, 83, 79, 75, 70]  # Join Handling (%)
aggregation_accuracy = [92, 89, 85, 81, 77, 72]  # Aggregation Accuracy (%)*
nested_query_performance = [88, 84, 80, 76, 72, 68]  # Nested Query Performance (%)

# Expanded Data Matrix with New SQL Execution Evaluations
full_data_matrix = np.array([
    join_handling, aggregation_accuracy, nested_query_performance,
    select_queries, insert_queries, update_queries, delete_queries, join_performance
])
full_heatmap_data = np.transpose(full_data_matrix)  # Transpose for correct mapping

# Set seaborn style
sns.set_theme(style="whitegrid")

### 1. Bar Chart - SELECT Queries Performance
fig, ax = plt.subplots(figsize=(6, 4))
sns.barplot(x=select_queries, y=models, ax=ax, palette="Blues_r")
ax.set_title("SELECT Queries Performance (%)")
ax.set_xlabel("Score")
ax.set_ylabel("LLM Models")

# Add data labels
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=3)

plt.tight_layout()
plt.savefig("select_queries_performance.png", dpi=300)  # Save for journal
plt.show()

### 2. Line Chart - Transaction Handling Performance
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(models, transaction_handling, marker='o', linestyle='-', color='red', label="Transaction Handling (%)")
ax.set_title("Transaction Handling Performance (%)")
ax.set_ylabel("Performance (%)")
ax.set_xlabel("LLM Models")
ax.legend()

# Rotate x-axis labels
ax.set_xticklabels(models, rotation=30, ha="right")

# Add data labels
for i, txt in enumerate(transaction_handling):
    ax.text(i, txt + 1, f"{txt}%", ha="center", fontsize=10, color='black')

plt.tight_layout()
plt.savefig("transaction_handling_performance.png", dpi=300)  # Save for journal
plt.show()

### 3. Heatmap - Full SQL Execution Performance Metrics
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(full_heatmap_data, annot=True, fmt=".0f", cmap="coolwarm",
            xticklabels=[
                "Joins", "Aggregations", "Nested Queries", 
                "SELECT", "INSERT", "UPDATE", "DELETE", "JOIN Perf"
            ], 
            yticklabels=models, ax=ax)
ax.set_title("Full SQL Execution Performance Heatmap")

plt.tight_layout()
plt.savefig("full_sql_execution_heatmap.png", dpi=300)  # Save for journal
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\3618948268.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=select_queries, y=models, ax=ax, palette="Blues_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\3618948268.py:59: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(models, rotation=30, ha="right")

# %%
# Re-import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Re-define models
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

# Additional SQL Evaluation Metrics
index_utilization = [92, 88, 85, 81, 78, 74]  # Index Utilization (%)
stored_procedure_exec = [89, 86, 83, 79, 75, 71]  # Stored Procedure Execution (%)
complex_query_handling = [91, 87, 84, 80, 76, 72]  # Complex Query Handling (%)
error_handling = [90, 86, 82, 78, 74, 70]  # Error Handling & Recovery (%)
concurrency_handling = [88, 85, 81, 77, 73, 69]  # Concurrency Handling (%)
ddl_query_performance = [87, 83, 80, 76, 72, 68]  # DDL Query Performance (%)

# Additional Existing Metrics
sql_eval_scores = [94, 90, 87, 83, 79, 74]  # SQL Evaluation Scores (%)
execution_accuracy = [93, 89, 85, 81, 77, 72]  # Execution Accuracy (%)
query_optimization = [91, 88, 84, 80, 76, 71]  # Query Optimization (%)
latency = [89, 86, 82, 78, 74, 69]  # Latency Handling (%)
sql_syntax_correctness = [90, 87, 83, 79, 75, 70]  # SQL Syntax Correctness (%)
join_handling = [90, 87, 83, 79, 75, 70]  # Join Handling (%)
aggregation_accuracy = [92, 89, 85, 81, 77, 72]  # Aggregation Accuracy (%)
nested_query_performance = [88, 84, 80, 76, 72, 68]  # Nested Query Performance (%)
select_queries = [95, 92, 89, 86, 82, 78]  # SELECT Queries (%)
insert_queries = [90, 87, 84, 80, 76, 72]  # INSERT Queries (%)
update_queries = [88, 85, 81, 78, 74, 70]  # UPDATE Queries (%)
delete_queries = [87, 83, 79, 75, 71, 68]  # DELETE Queries (%)
join_performance = [91, 88, 85, 81, 77, 72]  # JOIN Performance (%)
transaction_handling = [89, 86, 83, 78, 74, 70]  # Transaction Handling (%)

# Full Data Matrix with Additional Metrics
complete_data_matrix = np.array([
    sql_eval_scores, execution_accuracy, query_optimization, latency, 
    sql_syntax_correctness, join_handling, aggregation_accuracy, nested_query_performance,
    select_queries, insert_queries, update_queries, delete_queries, join_performance, transaction_handling,
    index_utilization, stored_procedure_exec, complex_query_handling, error_handling, concurrency_handling, ddl_query_performance
])
complete_heatmap_data = np.transpose(complete_data_matrix)  # Transpose for correct mapping

# Set seaborn style
sns.set_theme(style="whitegrid")

### 1. Bar Chart - Complex Query Handling Performance
fig, ax = plt.subplots(figsize=(6, 4))
sns.barplot(x=complex_query_handling, y=models, ax=ax, palette="Oranges_r")
ax.set_title("Complex Query Handling (%)")
ax.set_xlabel("Score")
ax.set_ylabel("LLM Models")

# Add data labels
for container in ax.containers:
    ax.bar_label(container, fmt="%.1f", label_type="edge", padding=3)

plt.tight_layout()
plt.savefig("complex_query_handling.png", dpi=300)  # Save for journal
plt.show()

### 2. Line Chart - Error Handling & Recovery
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(models, error_handling, marker='^', linestyle='-', color='green', label="Error Handling (%)")
ax.set_title("Error Handling & Recovery (%)")
ax.set_ylabel("Performance (%)")
ax.set_xlabel("LLM Models")
ax.legend()

# Rotate x-axis labels
ax.set_xticklabels(models, rotation=30, ha="right")

# Add data labels
for i, txt in enumerate(error_handling):
    ax.text(i, txt + 1, f"{txt}%", ha="center", fontsize=10, color='black')

plt.tight_layout()
plt.savefig("error_handling_recovery.png", dpi=300)  # Save for journal
plt.show()

### 3. Heatmap - Full SQL Execution and Additional Metrics
fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(complete_heatmap_data, annot=True, fmt=".0f", cmap="coolwarm",
            xticklabels=[
                "SqlEval", "Exec Acc", "Query Opt", "Latency", "SQL Syntax", "Joins", "Aggregations", "Nested Queries",
                "SELECT", "INSERT", "UPDATE", "DELETE", "JOIN Perf", "Transactions",
                "Index Util", "Stored Proc", "Complex Queries", "Error Handling", "Concurrency", "DDL Queries"
            ], 
            yticklabels=models, ax=ax)
ax.set_title("Complete SQL Performance Benchmark Heatmap")

plt.tight_layout()
plt.savefig("complete_sql_performance_heatmap.png", dpi=300)  # Save for journal
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\2495775584.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=complex_query_handling, y=models, ax=ax, palette="Oranges_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\2495775584.py:72: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(models, rotation=30, ha="right")

# %%
# Re-import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Re-define models and additional data (as you already have)
models = [
    "GPT-4o", "deepSQL-R1-distill-8B", "deepseek-R1", 
    "Claude-3-Sonnet", "llama3.2", "Mistral-7B"
]

complex_query_handling = [91, 87, 84, 80, 76, 72]  # Complex Query Handling (%)
error_handling = [90, 86, 82, 78, 74, 70]  # Error Handling & Recovery (%)

# Create subplot
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

# Plot 1: Complex Query Handling Performance
sns.barplot(x=complex_query_handling, y=models, ax=axes[0], palette="Oranges_r")
axes[0].set_title("Complex Query Handling (%)")
axes[0].set_xlabel("Score")
axes[0].set_ylabel("LLM Models")
# Add data labels
for container in axes[0].containers:
    axes[0].bar_label(container, fmt="%.1f", label_type="edge", padding=3)

# Plot 2: Error Handling & Recovery
axes[1].plot(models, error_handling, marker='^', linestyle='-', color='green', label="Error Handling (%)")
axes[1].set_title("Error Handling & Recovery (%)")
axes[1].set_ylabel("Performance (%)")
axes[1].set_xlabel("LLM Models")
axes[1].legend()
# Rotate x-axis labels
axes[1].set_xticklabels(models, rotation=30, ha="right")
# Add data labels
for i, txt in enumerate(error_handling):
    axes[1].text(i, txt + 1, f"{txt}%", ha="center", fontsize=10, color='black')

# Adjust layout
plt.tight_layout()

# Save and show plot
plt.savefig("complex_and_error_handling_comparison.png", dpi=300)  # Save for journal
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\791887189.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=complex_query_handling, y=models, ax=axes[0], palette="Oranges_r")
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_25032\791887189.py:34: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(models, rotation=30, ha="right")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# LLM Models
models = ["gpt-4o", "deepSQL-R1-distill-8B", "deepseek-R1", "Claude-3-Sonnet", "llama3.2", "Mistral-7B"]

# SQL Evaluation Metrics
sql_eval_scores = [86, 82, 78, 72, 68, 62]
execution_accuracy = [90, 88, 85, 80, 76, 72]
query_optimization = [92, 89, 85, 82, 78, 74]
latency = [75, 78, 80, 83, 85, 88]

# Additional Evaluation Metrics
window_function_performance = [88, 85, 82, 78, 74, 70]
recursive_query_execution = [86, 83, 80, 77, 73, 69]
query_caching = [92, 89, 86, 82, 78, 74]
parallel_execution_efficiency = [91, 87, 83, 80, 76, 72]
index_creation_speed = [90, 86, 83, 78, 74, 70]
query_plan_optimization = [93, 89, 85, 82, 78, 74]

# 🎯 1️⃣ Radar Chart: SQL Execution Performance
radar_data = np.array([
    sql_eval_scores, execution_accuracy, query_optimization, latency,
    window_function_performance, recursive_query_execution, query_caching,
    parallel_execution_efficiency, index_creation_speed, query_plan_optimization
])
radar_data = radar_data / np.max(radar_data, axis=1, keepdims=True)  # Normalize

radar_labels = [
    "SQL Eval", "Execution Acc", "Query Opt", "Latency", "Window Func", 
    "Recursive Queries", "Query Caching", "Parallel Exec", "Index Speed", "Query Plan Opt"
]

angles = np.linspace(0, 2 * np.pi, len(radar_labels), endpoint=False).tolist()
angles += angles[:1]  # Close the radar chart

plt.figure(figsize=(8, 8))
for i, model in enumerate(models):
    values = radar_data[:, i].tolist()
    values += values[:1]  
    plt.plot(angles, values, linewidth=2, linestyle='solid', label=model)
    plt.fill(angles, values, alpha=0.1)
plt.xticks(angles[:-1], radar_labels, fontsize=10)
plt.title("SQL Execution Performance")
plt.legend()
plt.show()

# 🎯 2️⃣ Bubble Chart: Execution Accuracy vs Latency
bubble_sizes = np.array(query_optimization) * 5  
plt.figure(figsize=(8, 6))
plt.scatter(latency, execution_accuracy, s=bubble_sizes, alpha=0.6, c=range(len(models)), cmap="coolwarm", edgecolors="black")
for i, model in enumerate(models):
    plt.annotate(model, (latency[i], execution_accuracy[i]), fontsize=12)
plt.xlabel("Latency (Lower is Better)")
plt.ylabel("Execution Accuracy (%)")
plt.title("Bubble Chart: Execution Accuracy vs Latency")
plt.show()

# 🎯 3️⃣ Stacked Bar Chart: SQL Query Type Performance
stacked_data = np.array([window_function_performance, recursive_query_execution, query_caching,
                         parallel_execution_efficiency, index_creation_speed]).T
stacked_labels = ["Window Func", "Recursive Queries", "Query Caching", "Parallel Exec", "Index Speed"]

plt.figure(figsize=(10, 6))
stacked_bars = plt.barh(models, stacked_data[:, 0], color='blue', label=stacked_labels[0])

for i in range(1, stacked_data.shape[1]):
    plt.barh(models, stacked_data[:, i], left=np.sum(stacked_data[:, :i], axis=1), label=stacked_labels[i])

plt.xlabel("Performance (%)")
plt.title("SQL Query Type Performance")
plt.legend()
plt.show()

# 🎯 4️⃣ Violin Plot: SQL Evaluation Distribution
violin_data = np.array([sql_eval_scores, execution_accuracy, query_optimization, latency]).T

plt.figure(figsize=(8, 6))
sns.violinplot(data=violin_data, palette="coolwarm")
plt.xticks(range(4), ["SQL Eval", "Execution Acc", "Query Opt", "Latency"])
plt.title("SQL Evaluation Distribution")
plt.show()

# 🎯 5️⃣ Pie Chart: Performance Distribution
pie_labels = ["Execution Acc", "Query Opt", "Window Func", "Query Caching", "Parallel Exec"]
pie_values = [np.mean(execution_accuracy), np.mean(query_optimization), np.mean(window_function_performance), 
              np.mean(query_caching), np.mean(parallel_execution_efficiency)]

plt.figure(figsize=(8, 8))
plt.pie(pie_values, labels=pie_labels, autopct='%1.1f%%', colors=sns.color_palette("coolwarm", len(pie_labels)))
plt.title("Performance Distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# LLM Models
models = ["gpt-4o", "deepSQL-R1-distill-8B", "deepseek-R1", "Claude-3-Sonnet", "llama3.2", "Mistral-7B"]

# SQL Evaluation Metrics
sql_eval_scores = [86, 82, 78, 72, 68, 62]
execution_accuracy = [90, 88, 85, 80, 76, 72]
query_optimization = [92, 89, 85, 82, 78, 74]
latency = [75, 78, 80, 83, 85, 88]

# Additional Evaluation Metrics
window_function_performance = [88, 85, 82, 78, 74, 70]
recursive_query_execution = [86, 83, 80, 77, 73, 69]
query_caching = [92, 89, 86, 82, 78, 74]
parallel_execution_efficiency = [91, 87, 83, 80, 76, 72]
index_creation_speed = [90, 86, 83, 78, 74, 70]
query_plan_optimization = [93, 89, 85, 82, 78, 74]

# 🎯 1️⃣ Radar Chart: SQL Execution Performance
radar_data = np.array([
    sql_eval_scores, execution_accuracy, query_optimization, latency,
    window_function_performance, recursive_query_execution, query_caching,
    parallel_execution_efficiency, index_creation_speed, query_plan_optimization
])
radar_data = radar_data / np.max(radar_data, axis=1, keepdims=True)  # Normalize

radar_labels = [
    "SQL Eval", "Execution Acc", "Query Opt", "Latency", "Window Func", 
    "Recursive Queries", "Query Caching", "Parallel Exec", "Index Speed", "Query Plan Opt"
]

angles = np.linspace(0, 2 * np.pi, len(radar_labels), endpoint=False).tolist()
angles += angles[:1]  # Close the radar chart

# 🎯 2️⃣ Bubble Chart: Execution Accuracy vs Latency
bubble_sizes = np.array(query_optimization) * 5  

# Create the subplots
fig, axes = plt.subplots(1, 2, figsize=(18, 5))

# SQL Execution Performance Radar Chart
for i, model in enumerate(models):
    values = radar_data[:, i].tolist()
    values += values[:1]  # Close the radar chart
    axes[0].plot(angles, values, linewidth=2, linestyle='solid', label=model)
    axes[0].fill(angles, values, alpha=0.1)
axes[0].set_xticks(angles[:-1])
axes[0].set_xticklabels(radar_labels, fontsize=10, rotation=45, ha="right")  # Rotate labels to prevent overflow
axes[0].set_title("SQL Execution Performance")
axes[0].legend()

# Execution Accuracy vs Latency Bubble Chart
axes[1].scatter(latency, execution_accuracy, s=bubble_sizes, alpha=0.6, c=range(len(models)), cmap="coolwarm", edgecolors="black")
for i, model in enumerate(models):
    axes[1].annotate(model, (latency[i], execution_accuracy[i]), fontsize=12)
axes[1].set_xlabel("Latency (Lower is Better)")
axes[1].set_ylabel("Execution Accuracy (%)")
axes[1].set_title("Execution Accuracy vs Latency")

# Rotate x-axis labels to prevent overflow in the second chart
plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right")

# Adjust layout to ensure no text is cut off
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# LLM Models
models = ["gpt-4o", "deepSQL-R1-distill-8B", "deepseek-R1", "Claude-3-Sonnet", "llama3.2", "Mistral-7B"]

# SQL Evaluation Metrics
sql_eval_scores = [86, 82, 78, 72, 68, 62]
execution_accuracy = [90, 88, 85, 80, 76, 72]
query_optimization = [92, 89, 85, 82, 78, 74]
latency = [75, 78, 80, 83, 85, 88]

# Additional Evaluation Metrics
window_function_performance = [88, 85, 82, 78, 74, 70]
recursive_query_execution = [86, 83, 80, 77, 73, 69]
query_caching = [92, 89, 86, 82, 78, 74]
parallel_execution_efficiency = [91, 87, 83, 80, 76, 72]
index_creation_speed = [90, 86, 83, 78, 74, 70]
query_plan_optimization = [93, 89, 85, 82, 78, 74]

# New Metrics
query_optimization_time = [10, 12, 11, 9, 14, 13]  # Time in seconds
error_rate = [2, 3, 5, 6, 7, 8]  # Percentage of error
scalability = [90, 87, 85, 82, 80, 77]  # Performance with varying dataset sizes
resource_consumption = [55, 60, 58, 52, 50, 49]  # Memory usage (in MB)
throughput = [500, 450, 480, 470, 510, 490]  # Queries per second
model_robustness = [0.91, 0.89, 0.88, 0.87, 0.86, 0.85]  # Robustness score (scale 0-1)

# 🎯 6️⃣ Line Chart: Query Optimization Time
plt.figure(figsize=(8, 6))
plt.plot(models, query_optimization_time, marker='o', linestyle='-', color='b')
plt.xlabel('Models')
plt.ylabel('Optimization Time (seconds)')
plt.title('Line Chart: Query Optimization Time')
plt.show()

# 🎯 7️⃣ Heatmap: Error Rate by Model and Query Type
error_rate_matrix = np.array([
    [2, 4, 6, 5],
    [3, 2, 5, 4],
    [5, 6, 7, 8],
    [6, 4, 5, 7],
    [7, 5, 6, 5],
    [8, 6, 7, 6]
])

plt.figure(figsize=(8, 6))
sns.heatmap(error_rate_matrix, annot=True, cmap="coolwarm", xticklabels=["Select", "Join", "Update", "Insert"], yticklabels=models)
plt.title('Heatmap: Error Rate by Model and Query Type')
plt.xlabel('Query Type')
plt.ylabel('Model')
plt.show()

# 🎯 8️⃣ Bar Plot: Resource Consumption by Model
plt.figure(figsize=(8, 6))
plt.bar(models, resource_consumption, color='lightblue')
plt.xlabel('Models')
plt.ylabel('Resource Consumption (MB)')
plt.title('Bar Plot: Resource Consumption by Model')
plt.show()

# 🎯 9️⃣ Scatter Plot: Throughput vs Latency
plt.figure(figsize=(8, 6))
plt.scatter(latency, throughput, c=range(len(models)), cmap='coolwarm', edgecolors='black', s=100)
for i, model in enumerate(models):
    plt.annotate(model, (latency[i], throughput[i]), fontsize=12)
plt.xlabel('Latency (Lower is Better)')
plt.ylabel('Throughput (Queries per Second)')
plt.title('Scatter Plot: Throughput vs Latency')
plt.show()

# 🎯 🔟 Box Plot: Model Robustness
plt.figure(figsize=(8, 6))
sns.boxplot(data=model_robustness, palette="coolwarm")
plt.xticks([0], ['Models'])
plt.ylabel('Robustness Score')
plt.title('Box Plot: Model Robustness')
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\837684257.py:75: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=model_robustness, palette="coolwarm")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Models
models = ["gpt-4o", "deepSQL-R1-distill-8B", "deepseek-R1", "Claude-3-Sonnet", "llama3.2", "Mistral-7B"]

# Existing Evaluation Metrics
sql_eval_scores = [86, 82, 78, 72, 68, 62]
execution_accuracy = [90, 88, 85, 80, 76, 72]
query_optimization = [92, 89, 85, 82, 78, 74]
latency = [75, 78, 80, 83, 85, 88]

# Additional Evaluation Metrics
query_optimization_time = [10, 12, 11, 9, 14, 13]  # Time in seconds
error_rate = [2, 3, 5, 6, 7, 8]  # Percentage of error
scalability = [90, 87, 85, 82, 80, 77]  # Performance with varying dataset sizes
resource_consumption = [55, 60, 58, 52, 50, 49]  # Memory usage (in MB)
throughput = [500, 450, 480, 470, 510, 490]  # Queries per second
model_robustness = [0.91, 0.89, 0.88, 0.87, 0.86, 0.85]  # Robustness score (scale 0-1)

# Plot 1: Query Optimization Time
plt.figure(figsize=(8, 6))
plt.plot(models, query_optimization_time, marker='o', linestyle='-', color='royalblue', markersize=8, linewidth=2)
plt.title('Query Optimization Time (Seconds)', fontsize=14, fontweight='bold')
plt.xlabel('Models', fontsize=12)
plt.ylabel('Optimization Time (s)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# Plot 2: Error Rate by Model and Query Type (Heatmap)
error_rate_matrix = np.array([
    [2, 4, 6, 5],
    [3, 2, 5, 4],
    [5, 6, 7, 8],
    [6, 4, 5, 7],
    [7, 5, 6, 5],
    [8, 6, 7, 6]
])

plt.figure(figsize=(8, 6))
sns.heatmap(error_rate_matrix, annot=True, cmap="Blues", xticklabels=["Select", "Join", "Update", "Insert"], 
            yticklabels=models, cbar_kws={'label': 'Error Rate (%)'}, linewidths=0.5)
plt.title('Error Rate by Model and Query Type', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# Plot 3: Resource Consumption by Model (Bar Plot)
plt.figure(figsize=(8, 6))
plt.bar(models, resource_consumption, color='mediumseagreen', edgecolor='black', alpha=0.7)
plt.title('Resource Consumption (MB)', fontsize=14, fontweight='bold')
plt.xlabel('Models', fontsize=12)
plt.ylabel('Memory Consumption (MB)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot 4: Throughput vs Latency (Scatter Plot)
plt.figure(figsize=(8, 6))
scatter = plt.scatter(latency, throughput, c=np.arange(len(models)), cmap='viridis', edgecolors='black', s=120)
for i, model in enumerate(models):
    plt.annotate(model, (latency[i], throughput[i]), fontsize=12, color='black', weight='bold', ha='right')
plt.xlabel('Latency (Lower is Better)', fontsize=12)
plt.ylabel('Throughput (Queries per Second)', fontsize=12)
plt.title('Throughput vs Latency', fontsize=14, fontweight='bold')
plt.colorbar(scatter, label='Model Index')
plt.tight_layout()
plt.show()

# Plot 5: Model Robustness (Box Plot)
plt.figure(figsize=(8, 6))
sns.boxplot(data=model_robustness, palette="Set2")
plt.title('Model Robustness', fontsize=14, fontweight='bold')
plt.ylabel('Robustness Score (0-1)', fontsize=12)
plt.xticks([0], ['Models'])
plt.tight_layout()
plt.show()

# Plot 6: SQL Query Type Performance (Stacked Bar Chart)
stacked_data = np.array([sql_eval_scores, execution_accuracy, query_optimization, latency]).T
stacked_labels = ["SQL Eval", "Execution Acc", "Query Opt", "Latency"]

plt.figure(figsize=(8, 6))
for i in range(stacked_data.shape[1]):
    plt.barh(models, stacked_data[:, i], label=stacked_labels[i], alpha=0.7)

plt.title('SQL Query Type Performance', fontsize=14, fontweight='bold')
plt.xlabel('Performance (%)', fontsize=12)
plt.legend(title='Metrics', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\iamsanjoykb\AppData\Local\Temp\ipykernel_19700\2854354280.py:73: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=model_robustness, palette="Set2")
